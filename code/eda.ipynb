# %%
import pandas as pd

# %%
# Prediction dist
preds = pd.read_csv("../predictions.csv")
preds["pred_class"] = preds[["normal", "benign", "malignant"]].idxmax(axis=1)
print(preds["pred_class"].value_counts().reindex(["normal", "benign", "malignant"], fill_value=0))
# Out:
# pred_class
# normal       74
# benign       10
# malignant    15
# Name: count, dtype: int64
